# %%
from cmcrameri import cm
from tqdm import tqdm
import pandas as pd 
import seaborn as sns
from common import *
from models import *

# %% [markdown]
# # Univariate plots

# %%
plot_predictions = False

variate = ["univariate","multivariate"][0]
ind = 1
model_read = ["simpleRNN", "convGRU", "LSTM"][ind]
model_name = ["RNN","convGRU","LSTM"][ind]


preds_file = f"{REPORT_DATA}/best_models/{variate}_{model_read}_preds_best.csv"
preds_df = pd.read_csv(preds_file, index_col=0)

results_file = f"{REPORT_DATA}/best_models/{variate}_{model_read}_results_best.csv"
results_df = pd.read_csv(results_file, index_col=0)

train_val_loss_file = f"{REPORT_DATA}/best_models/{variate}_{model_read}_train_val_losses_best.csv"
train_val_loss_df = pd.read_csv(train_val_loss_file, index_col=0)

print(variate)
print(model_read)
print(model_name)
print(preds_file)
print(results_file)
print(train_val_loss_file)
display(preds_df)
display(results_df)
display(train_val_loss_df)
# Out:
# univariate
# convGRU
# convGRU
# ../data/report_data//best_models/univariate_convGRU_preds_best.csv
# ../data/report_data//best_models/univariate_convGRU_results_best.csv
# ../data/report_data//best_models/univariate_convGRU_train_val_losses_best.csv
#            x1        x2        x3        x4        x5        x6        x7  \
# 0    0.256492  0.257817  0.272026  0.272296  0.203352  0.163442  0.169411
# 1    0.251606  0.265151  0.286463  0.284914  0.216315  0.174045  0.183051
# 2    0.265660  0.266288  0.284181  0.291315  0.221510  0.179507  0.189035
# 3    0.249849  0.260205  0.281343  0.279682  0.206784  0.163692  0.170377
# 4    0.246884  0.257760  0.278813  0.277713  0.203081  0.159764  0.166623
# ..        ...       ...       ...       ...       ...       ...       ...
# 210  0.510129  0.530813  0.574037  0.573767  0.436560  0.353624  0.360082
# 211  0.525117  0.542297  0.585513  0.586016  0.437960  0.350553  0.361866
# 212  0.532089  0.551336  0.596927  0.600972  0.460364  0.378650  0.380078
# 213  0.537140  0.564639  0.613092  0.616114  0.458738  0.376366  0.374949
# 214  0.537414  0.558272  0.600074  0.604542  0.443787  0.354552  0.363390
#
#            x8        x9       x10  ...   t_hat15   t_hat16   t_hat17  \
# 0    0.334032  0.359758  0.395549  ...  0.350908  0.332513  0.337551
# 1    0.368409  0.390223  0.415293  ...  0.370921  0.360649  0.360695
# 2    0.381666  0.400715  0.420648  ...  0.361594  0.350011  0.350348
# 3    0.341821  0.356960  0.385008  ...  0.371214  0.360175  0.398835
# 4    0.336055  0.353540  0.381327  ...  0.365452  0.375282  0.423297
# ..        ...       ...       ...  ...       ...       ...       ...
# 210  0.690309  0.668921  0.715720  ...  0.541236  0.593234  0.578325
# 211  0.721315  0.738867  0.792939  ...  0.626414  0.656830  0.599101
# 212  0.741612  0.749592  0.806659  ...  0.598963  0.635238  0.579384
# 213  0.726857  0.741198  0.797624  ...  0.661469  0.714270  0.644522
# 214  0.704389  0.726898  0.780055  ...  0.665251  0.704580  0.615082
#
#       t_hat18   t_hat19   t_hat20   t_hat21   t_hat22   t_hat23   t_hat24
# 0    0.331386  0.247485  0.192998  0.204434  0.214465  0.238715  0.238625
# 1    0.351732  0.248028  0.188715  0.202625  0.218132  0.240295  0.241340
# 2    0.341945  0.233473  0.166265  0.182473  0.194945  0.217781  0.223378
# 3    0.393835  0.324614  0.264515  0.277956  0.266225  0.261909  0.249121
# 4    0.422434  0.338913  0.239491  0.263662  0.262487  0.285219  0.252764
# ..        ...       ...       ...       ...       ...       ...       ...
# 210  0.573272  0.435529  0.333529  0.371026  0.412050  0.451658  0.421704
# 211  0.606394  0.440213  0.347600  0.373198  0.404752  0.454433  0.448595
# 212  0.583476  0.443171  0.348315  0.378410  0.424768  0.471193  0.459455
# 213  0.721726  0.666196  0.697816  0.763951  0.716365  0.604495  0.482345
# 214  0.633677  0.532788  0.471289  0.498540  0.541054  0.586689  0.550484
#
# [215 rows x 216 columns]
#    model  batch_size  learning_rate  epoch  neurons   mse_all      mse1  \
# 0    0.0       100.0           0.01   25.0    128.0  0.051396  0.001705
#
#        mse2      mse3     mse4  ...    mse15     mse16     mse17     mse18  \
# 0  0.003682  0.004827  0.00497  ...  0.01205  0.013341  0.015196  0.013051
#
#       mse19     mse20     mse21     mse22     mse23     mse24
# 0  0.008225  0.007387  0.007217  0.006088  0.005772  0.005628
#
# [1 rows x 30 columns]
#     training_loss  validation_loss
# 0        0.011120         0.010378
# 1        0.005550         0.009064
# 2        0.006550         0.009931
# 3        0.004751         0.005806
# 4        0.003689         0.006112
# 5        0.003469         0.004650
# 6        0.003297         0.004846
# 7        0.003383         0.005712
# 8        0.003288         0.008694
# 9        0.003820         0.009822
# 10       0.003825         0.004748
# 11       0.002889         0.003281
# 12       0.002017         0.002784
# 13       0.001641         0.004344
# 14       0.001670         0.005032
# 15       0.002081         0.003762
# 16       0.001383         0.001837
# 17       0.001106         0.001807
# 18       0.000872         0.002727
# 19       0.000868         0.001549
# 20       0.000836         0.001596
# 21       0.000715         0.002346
# 22       0.000727         0.001561
# 23       0.000662         0.001336
# 24       0.000595         0.001578

# %% [markdown]
# # Plot trainining evaluation

# %%
ax = train_val_loss_df.plot(lw=2, markersize=10)
ax.set_xlabel("Epochs")
ax.set_ylabel("MSE loss")
plt.savefig(f"{REPORT_FIGURES}{variate}_train_evaluation_{model_name}.pdf")

# %% [markdown]
# # Predictions and plots

# %%
test_samples = [11, 98, train_val_loss_df.shape[0]-1]
horizon = 24


t_columns = [f"t{i}" for i in range(1,25)]
t_hat_columns = [f"t_hat{i}" for i in range(1,25)]


t = preds_df[t_columns].to_numpy()
t_hat = preds_df[t_hat_columns].to_numpy()
x_seq = preds_df.loc[:, :"x168"]
x_seq_columns = x_seq.columns
x_seq = x_seq.to_numpy()

hourly_mean = np.mean(t_hat, axis=0)
hourly_variance = np.var(t_hat, axis=0)
print(hourly_mean.shape)
print(hourly_variance.shape)

hourly_mean_t = np.mean(t, axis=0)
hourly_variance_t = np.var(t, axis=0)

if(plot_predictions):
    x_plot_seq_len = x_seq[test_samples[0]].shape[0]
    x_plot_seq = np.arange(x_plot_seq_len + horizon)

    for idx in test_samples:
        plt.figure(figsize=(6,4))
        plt.plot(x_plot_seq[:-horizon], x_seq[idx] , label="Historical sequence")
        plt.plot(x_plot_seq[-horizon:], t[idx], label="Target")
        plt.plot(x_plot_seq[-horizon:], t_hat[idx], label="Prediciton")
        plt.xlim([100,200 ])
        plt.xlabel("Hour")
        plt.ylabel("Price")
        plt.legend()
        plt.savefig(f"{REPORT_FIGURES}{variate}_predictions_{model_name}_testsample{idx}.pdf")
# Out:
# (24,)
# (24,)

# %% [markdown]
# # MSE relative to hours of day

# %%
mse_hour_colums = ["mse1","mse2","mse3","mse4","mse5","mse6","mse7","mse8","mse9","mse10","mse11","mse12",
                   "mse13","mse14","mse15","mse16","mse17","mse18","mse19","mse20","mse21","mse22","mse23","mse24"]
mse_hour = results_df[mse_hour_colums].to_numpy()[0]
x_plot = np.arange(mse_hour.shape[0])
x_plot_tick = [f"{i}" for i in range(0, 24)]
# print(x_plot)
# plt.figure(figsize=(7,3))
# plt.xticks(x_plot,x_plot_tick)
# plt.plot(x_plot, mse_hour, color="blue")
# plt.ylim(0, 0.06)
# plt.grid()
# plt.xlabel("Hour")
# plt.ylabel("MSE")

# %% [markdown]
# # MSE, MEAN and Variance for each hour relative to predictions

# %%
fig, axs = plt.subplots(3, sharex=True,figsize=(7,4))
axs[0].plot(x_plot, mse_hour, color="blue", label="MSE for hour")
axs[0].set_ylabel("MSE")
axs[0].set_ylim([0, 0.08])
axs[0].grid()
axs[1].plot(x_plot, hourly_mean_t, color="black", label="Mean of target")
axs[1].plot(x_plot, hourly_mean, color="red", label="Mean of prediction")
axs[1].set_ylabel("Mean")
# axs[1].set_ylim([0, 0.6])
axs[1].grid()
axs[2].plot(x_plot, hourly_variance_t, color="black", label="Variance of target")
axs[2].plot(x_plot, hourly_variance, color="red", label="Variance of prediction")
axs[2].set_ylabel("Variance")
# axs[2].set_ylim([0, 0.25])
axs[2].grid()
axs[2].set_xlabel("Hour")
ax = plt.xticks(x_plot,x_plot_tick)
plt.savefig(f"{REPORT_FIGURES}{variate}_hourly_stats_{model_name}.pdf")

# %% [markdown]
# # Plotting the whole test set

# %%
df = pd.read_csv(f"../data/input_data/MAIN_DATASET.csv", index_col=[0])

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df["scaled_price"] = scaler.fit_transform(df["NO2_price"].values.reshape(-1,1))


time_steps = 24
order = 24

train= df["scaled_price"][:int(len(df)*0.9)].to_numpy()
# train = df["NO2_price_diff"][:-time_steps].to_numpy()

test = df["scaled_price"][int(len(df)*0.9):].to_numpy()
#slice som vals to split into equal arrays of 24 hours:

test = test[len(test)%time_steps:]

print(test.shape)
# Out:
# (5160,)

# %%
targets_df = preds_df.loc[:, "t1":"t24"]
print(targets_df.shape)

predictions_df = preds_df.loc[:, "t_hat1":"t_hat24"]
# print(targets_df.columns)
# print(predictions_df.columns)
targets = targets_df.to_numpy()[:,  22:23].flatten()
print(targets.shape)
predictions = predictions_df.to_numpy()[:, 22:23].flatten()
x_ = np.arange(predictions.shape[0])
plt.figure(figsize=(20,10))
plt.plot(x_, targets[:], label="Target")
# plt.plot(x_, test, label="test")
plt.plot(x_, predictions[:], label="Forecasted")
plt.legend()
# Out:
# (215, 24)
# (215,)

# %%
price_all = df["NO2_price"].to_numpy()


params = {'legend.fontsize': 16,
          'axes.labelsize': 16,
          'axes.titlesize': 16,
          'xtick.labelsize':16,
          'ytick.labelsize':16}
plt.rcParams.update(params)
plt.figure(figsize=(16,8))
plt.axvline(x=43200,  linewidth=3, c="pink", label="NordLink in trial operation from 2020-12-09")
plt.axvline(x=50300,  linewidth=3, c="orange", alpha=0.6, label="North Sea Link in operation: 2021-10-01")
plt.plot(np.arange(price_all.shape[0]), price_all)
plt.ylabel("Price [EUR / MWh]")
plt.xlabel("Hours between 2016-2021")
plt.legend()
plt.savefig(f"{REPORT_FIGURES}price_2016_2021.pdf", bbox_inches='tight')

# %%
df = pd.read_csv(f"../data/input_data/MAIN_DATASET.csv", index_col=[0])
display(df)
df = df[["NO2_price","NO2_load_actual","NO2_load_forecasted","NO2_load_delta","NO2_generation_actual","NO2_generation_forecast","NO2_generation_delta","NO2_Fyllingsgrad_NVE"]]
df.corr()
# Out:
#                            index  NO2_price  NO2_load_actual  \
# 0      2016-01-03 12:00:00+01:00      16.37             5099
# 1      2016-01-03 13:00:00+01:00      16.35             5134
# 2      2016-01-03 14:00:00+01:00      16.35             5113
# 3      2016-01-03 15:00:00+01:00      16.30             5198
# 4      2016-01-03 16:00:00+01:00      16.45             5280
# ...                          ...        ...              ...
# 51643  2021-11-24 07:00:00+01:00     114.88             4897
# 51644  2021-11-24 08:00:00+01:00     117.94             5001
# 51645  2021-11-24 09:00:00+01:00     118.36             4951
# 51646  2021-11-24 10:00:00+01:00     118.68             4878
# 51647  2021-11-24 11:00:00+01:00     117.96             4746
#
#        NO2_load_forecasted  NO2_load_delta  NO2_generation_actual  \
# 0                     5223             124                  16426
# 1                     5246             112                  16580
# 2                     5234             121                  16722
# 3                     5303             105                  17192
# 4                     5419             139                  17666
# ...                    ...             ...                    ...
# 51643                 4232            -665                  17432
# 51644                 4185            -816                  17822
# 51645                 4064            -887                  17784
# 51646                 4098            -780                  17800
# 51647                 4074            -672                  17406
#
#        NO2_generation_forecast  NO2_generation_delta  NO5_price  \
# 0                         8473                 -7953      17.94
# 1                         8452                 -8128      17.66
# 2                         8486                 -8236      17.66
# 3                         8576                 -8616      17.60
# 4                         8896                 -8770      18.61
# ...                        ...                   ...        ...
# 51643                     9054                 -8378     114.88
# 51644                     9086                 -8736     117.94
# 51645                     9072                 -8712     118.36
# 51646                     9135                 -8665     118.68
# 51647                     9122                 -8284     117.96
#
#        NO5_load_actual  NO5_load_forecasted  NO5_load_delta  \
# 0                 2659                 2542            -117
# 1                 2666                 2567             -99
# 2                 2674                 2561            -113
# 3                 2718                 2614            -104
# 4                 2775                 2641            -134
# ...                ...                  ...             ...
# 51643             2176                 2354             178
# 51644             2243                 2448             205
# 51645             2195                 2450             255
# 51646             2238                 2464             226
# 51647             2215                 2446             231
#
#        NO5_generation_actual  NO5_generation_forecast  NO5_generation_delta  \
# 0                       8802                     4404                 -4398
# 1                       9022                     4442                 -4580
# 2                       9308                     4520                 -4788
# 3                       9946                     4662                 -5284
# 4                      10378                     4831                 -5547
# ...                      ...                      ...                   ...
# 51643                   9644                     4980                 -4664
# 51644                  10882                     5488                 -5394
# 51645                  10602                     5351                 -5251
# 51646                  10496                     5348                 -5148
# 51647                  10174                     5177                 -4997
#
#        NO2_Fyllingsgrad_NVE  NO5_Fyllingsgrad_NVE                    dato_id  \
# 0                  0.890802              0.759365  2016-01-03 12:00:00+01:00
# 1                  0.890601              0.759098  2016-01-03 13:00:00+01:00
# 2                  0.890400              0.758831  2016-01-03 14:00:00+01:00
# 3                  0.890199              0.758564  2016-01-03 15:00:00+01:00
# 4                  0.889998              0.758297  2016-01-03 16:00:00+01:00
# ...                     ...                   ...                        ...
# 51643              0.636997              0.665980  2021-11-24 07:00:00+01:00
# 51644              0.636997              0.665980  2021-11-24 08:00:00+01:00
# 51645              0.636997              0.665980  2021-11-24 09:00:00+01:00
# 51646              0.636997              0.665980  2021-11-24 10:00:00+01:00
# 51647              0.636997              0.665980  2021-11-24 11:00:00+01:00
#
#            date_time
# 0      2016-01-03-12
# 1      2016-01-03-13
# 2      2016-01-03-14
# 3      2016-01-03-15
# 4      2016-01-03-16
# ...              ...
# 51643  2021-11-24-07
# 51644  2021-11-24-08
# 51645  2021-11-24-09
# 51646  2021-11-24-10
# 51647  2021-11-24-11
#
# [51648 rows x 19 columns]
#                          NO2_price  NO2_load_actual  NO2_load_forecasted  \
# NO2_price                 1.000000         0.144035             0.057381
# NO2_load_actual           0.144035         1.000000             0.919632
# NO2_load_forecasted       0.057381         0.919632             1.000000
# NO2_load_delta           -0.182682         0.056642             0.444240
# NO2_generation_actual     0.126253         0.801201             0.736625
# NO2_generation_forecast   0.125258         0.799051             0.734748
# NO2_generation_delta     -0.126069        -0.795788            -0.731548
# NO2_Fyllingsgrad_NVE     -0.263802        -0.057972            -0.050960
#
#                          NO2_load_delta  NO2_generation_actual  \
# NO2_price                     -0.182682               0.126253
# NO2_load_actual                0.056642               0.801201
# NO2_load_forecasted            0.444240               0.736625
# NO2_load_delta                 1.000000               0.044912
# NO2_generation_actual          0.044912               1.000000
# NO2_generation_forecast        0.045045               0.995380
# NO2_generation_delta          -0.044352              -0.995216
# NO2_Fyllingsgrad_NVE           0.002699               0.027150
#
#                          NO2_generation_forecast  NO2_generation_delta  \
# NO2_price                               0.125258             -0.126069
# NO2_load_actual                         0.799051             -0.795788
# NO2_load_forecasted                     0.734748             -0.731548
# NO2_load_delta                          0.045045             -0.044352
# NO2_generation_actual                   0.995380             -0.995216
# NO2_generation_forecast                 1.000000             -0.981237
# NO2_generation_delta                   -0.981237              1.000000
# NO2_Fyllingsgrad_NVE                    0.024113             -0.029984
#
#                          NO2_Fyllingsgrad_NVE
# NO2_price                           -0.263802
# NO2_load_actual                     -0.057972
# NO2_load_forecasted                 -0.050960
# NO2_load_delta                       0.002699
# NO2_generation_actual                0.027150
# NO2_generation_forecast              0.024113
# NO2_generation_delta                -0.029984
# NO2_Fyllingsgrad_NVE                 1.000000

# %%
# Create correlation matrix
corr_matrix = df.corr(method='spearman')
# corr_matrix = df.corr(method='pearson')
# Plot
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
sns.heatmap(abs(corr_matrix), annot=True, cmap = cm.lajolla, fmt='.2f', ax=axs)
plt.savefig("../figures/feature_corr_analysis.pdf", bbox_inches='tight');
